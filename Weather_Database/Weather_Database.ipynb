# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
! pip install citipy
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from citipy) (0.16)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'}
        city_weather = requests.get(city_url, headers).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    # If an error is experienced, skip the city.
    except Exception:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mildura
# Processing Record 2 of Set 1 | port hardy
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | menongue
# Processing Record 5 of Set 1 | geraldton
# Processing Record 6 of Set 1 | tondano
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | taseyevo
# Processing Record 9 of Set 1 | labuhan
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | nautla
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | moose factory
# Processing Record 14 of Set 1 | norman wells
# Processing Record 15 of Set 1 | egvekinot
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | lensk
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | souillac
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | lasem
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | vacaria
# Processing Record 35 of Set 1 | sao miguel do tapuio
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | nenton
# Processing Record 39 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | spasskoye
# Processing Record 44 of Set 1 | grindavik
# Processing Record 45 of Set 1 | kavaratti
# Processing Record 46 of Set 1 | nanortalik
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | havre-saint-pierre
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | college
# Processing Record 9 of Set 2 | zyryanka
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | aragarcas
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | gornopravdinsk
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | zacatepec
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | kilindoni
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | pangody
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | peniche
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | tateyama
# Processing Record 25 of Set 2 | bolshevik
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | staraya poltavka
# Processing Record 28 of Set 2 | nemuro
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | nouakchott
# Processing Record 32 of Set 2 | bismarck
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | san jose
# Processing Record 35 of Set 2 | ibanda
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | great yarmouth
# Processing Record 38 of Set 2 | akureyri
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | nome
# Processing Record 41 of Set 2 | healesville
# Processing Record 42 of Set 2 | palestina
# Processing Record 43 of Set 2 | ambilobe
# Processing Record 44 of Set 2 | sorong
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | pangnirtung
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | aswan
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | kruisfontein
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | ankazoabo
# Processing Record 5 of Set 3 | cooma
# Processing Record 6 of Set 3 | saint george
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | esperance
# Processing Record 10 of Set 3 | cabo san lucas
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | galle
# Processing Record 13 of Set 3 | hays
# Processing Record 14 of Set 3 | phuket
# Processing Record 15 of Set 3 | japura
# Processing Record 16 of Set 3 | pisco
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | candido mendes
# Processing Record 19 of Set 3 | santa ana
# Processing Record 20 of Set 3 | sencur
# Processing Record 21 of Set 3 | le port
# Processing Record 22 of Set 3 | saint anthony
# Processing Record 23 of Set 3 | camargo
# Processing Record 24 of Set 3 | bosaso
# Processing Record 25 of Set 3 | birao
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | sharan
# Processing Record 28 of Set 3 | riohacha
# Processing Record 29 of Set 3 | vardo
# Processing Record 30 of Set 3 | bonavista
# Processing Record 31 of Set 3 | arlit
# Processing Record 32 of Set 3 | lumberton
# Processing Record 33 of Set 3 | puerto ayora
# Processing Record 34 of Set 3 | pula
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | bloomingdale
# Processing Record 37 of Set 3 | ponta delgada
# Processing Record 38 of Set 3 | oktyabrskiy
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | pedernales
# Processing Record 41 of Set 3 | meadow lake
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | acapulco
# Processing Record 44 of Set 3 | paso de patria
# Processing Record 45 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 3 | bredasdorp
# Processing Record 47 of Set 3 | alofi
# Processing Record 48 of Set 3 | nelson bay
# Processing Record 49 of Set 3 | coihaique
# Processing Record 50 of Set 3 | flinders
# Processing Record 1 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 4 | haines junction
# Processing Record 3 of Set 4 | alekseyevskaya
# Processing Record 4 of Set 4 | la ronge
# Processing Record 5 of Set 4 | champua
# Processing Record 6 of Set 4 | zhuhai
# Processing Record 7 of Set 4 | yuci
# Processing Record 8 of Set 4 | aliwal north
# Processing Record 9 of Set 4 | sinnamary
# Processing Record 10 of Set 4 | yenagoa
# Processing Record 11 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 4 | mayo
# Processing Record 13 of Set 4 | sparks
# Processing Record 14 of Set 4 | malanje
# Processing Record 15 of Set 4 | rundu
# Processing Record 16 of Set 4 | talnakh
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | pacific grove
# Processing Record 19 of Set 4 | othonoi
# City not found. Skipping...
# Processing Record 20 of Set 4 | amapa
# Processing Record 21 of Set 4 | hay river
# Processing Record 22 of Set 4 | komsomolskiy
# Processing Record 23 of Set 4 | poya
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | ios
# Processing Record 26 of Set 4 | cubara
# Processing Record 27 of Set 4 | lompoc
# Processing Record 28 of Set 4 | bozeman
# Processing Record 29 of Set 4 | ayan
# Processing Record 30 of Set 4 | tatawin
# Processing Record 31 of Set 4 | russell
# Processing Record 32 of Set 4 | bilma
# Processing Record 33 of Set 4 | bursa
# Processing Record 34 of Set 4 | kuldur
# Processing Record 35 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 4 | weihe
# Processing Record 37 of Set 4 | kuytun
# Processing Record 38 of Set 4 | eyl
# Processing Record 39 of Set 4 | port macquarie
# Processing Record 40 of Set 4 | reading
# Processing Record 41 of Set 4 | malartic
# Processing Record 42 of Set 4 | sao gabriel da cachoeira
# Processing Record 43 of Set 4 | cap malheureux
# Processing Record 44 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 4 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 46 of Set 4 | jumla
# Processing Record 47 of Set 4 | airai
# Processing Record 48 of Set 4 | ilulissat
# Processing Record 49 of Set 4 | hobyo
# Processing Record 50 of Set 4 | la peca
# Processing Record 1 of Set 5 | karratha
# Processing Record 2 of Set 5 | mecca
# Processing Record 3 of Set 5 | acarau
# Processing Record 4 of Set 5 | dunedin
# Processing Record 5 of Set 5 | padang
# Processing Record 6 of Set 5 | saint-pierre
# Processing Record 7 of Set 5 | veraval
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | turukhansk
# Processing Record 10 of Set 5 | aguilas
# Processing Record 11 of Set 5 | faya
# Processing Record 12 of Set 5 | sandovo
# Processing Record 13 of Set 5 | lock haven
# Processing Record 14 of Set 5 | kothi
# Processing Record 15 of Set 5 | tagusao
# Processing Record 16 of Set 5 | yatou
# Processing Record 17 of Set 5 | beloha
# Processing Record 18 of Set 5 | codrington
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 5 | aklavik
# Processing Record 22 of Set 5 | luorong
# Processing Record 23 of Set 5 | joshimath
# Processing Record 24 of Set 5 | clarence town
# Processing Record 25 of Set 5 | petropavlovka
# Processing Record 26 of Set 5 | narasannapeta
# Processing Record 27 of Set 5 | vestmannaeyjar
# Processing Record 28 of Set 5 | trelew
# Processing Record 29 of Set 5 | adrar
# Processing Record 30 of Set 5 | aguimes
# Processing Record 31 of Set 5 | abu dhabi
# Processing Record 32 of Set 5 | huangcun
# Processing Record 33 of Set 5 | buala
# Processing Record 34 of Set 5 | kloulklubed
# Processing Record 35 of Set 5 | kargopol
# Processing Record 36 of Set 5 | kungurtug
# Processing Record 37 of Set 5 | indi
# Processing Record 38 of Set 5 | ternate
# Processing Record 39 of Set 5 | inuvik
# Processing Record 40 of Set 5 | russkaya polyana
# Processing Record 41 of Set 5 | iqaluit
# Processing Record 42 of Set 5 | buraydah
# Processing Record 43 of Set 5 | diffa
# Processing Record 44 of Set 5 | talas
# Processing Record 45 of Set 5 | chumikan
# Processing Record 46 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 5 | trinidad
# Processing Record 48 of Set 5 | tekax
# City not found. Skipping...
# Processing Record 49 of Set 5 | antofagasta
# Processing Record 50 of Set 5 | nikolskoye
# Processing Record 1 of Set 6 | rawson
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | tilichiki
# Processing Record 4 of Set 6 | kalabo
# Processing Record 5 of Set 6 | leh
# Processing Record 6 of Set 6 | lima
# Processing Record 7 of Set 6 | kutum
# Processing Record 8 of Set 6 | chimore
# Processing Record 9 of Set 6 | zavodouspenskoye
# Processing Record 10 of Set 6 | grand gaube
# Processing Record 11 of Set 6 | abiy adi
# City not found. Skipping...
# Processing Record 12 of Set 6 | umm kaddadah
# Processing Record 13 of Set 6 | palmas bellas
# Processing Record 14 of Set 6 | launceston
# Processing Record 15 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 6 | moerai
# Processing Record 17 of Set 6 | omsukchan
# Processing Record 18 of Set 6 | soweto
# Processing Record 19 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | jiayuguan
# Processing Record 21 of Set 6 | vrangel
# Processing Record 22 of Set 6 | nouadhibou
# Processing Record 23 of Set 6 | axim
# Processing Record 24 of Set 6 | manokwari
# Processing Record 25 of Set 6 | viedma
# Processing Record 26 of Set 6 | erdenet
# Processing Record 27 of Set 6 | antalaha
# Processing Record 28 of Set 6 | kunda
# Processing Record 29 of Set 6 | mandalgovi
# Processing Record 30 of Set 6 | margate
# Processing Record 31 of Set 6 | sorland
# Processing Record 32 of Set 6 | port-gentil
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | manta
# Processing Record 35 of Set 6 | touros
# Processing Record 36 of Set 6 | abha
# Processing Record 37 of Set 6 | gornorechenskiy
# Processing Record 38 of Set 6 | kahului
# Processing Record 39 of Set 6 | florianopolis
# Processing Record 40 of Set 6 | taoudenni
# Processing Record 41 of Set 6 | alice springs
# Processing Record 42 of Set 6 | kurilsk
# Processing Record 43 of Set 6 | deputatskiy
# Processing Record 44 of Set 6 | port hedland
# Processing Record 45 of Set 6 | new norfolk
# Processing Record 46 of Set 6 | saleilua
# City not found. Skipping...
# Processing Record 47 of Set 6 | zhigansk
# Processing Record 48 of Set 6 | mangrol
# Processing Record 49 of Set 6 | roald
# Processing Record 50 of Set 6 | hami
# Processing Record 1 of Set 7 | ribeira grande
# Processing Record 2 of Set 7 | zemio
# Processing Record 3 of Set 7 | sola
# Processing Record 4 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 7 | sobolevo
# Processing Record 6 of Set 7 | batagay
# Processing Record 7 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 7 | vengerovo
# Processing Record 9 of Set 7 | klaksvik
# Processing Record 10 of Set 7 | huarmey
# Processing Record 11 of Set 7 | brainerd
# Processing Record 12 of Set 7 | goundam
# Processing Record 13 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 7 | te anau
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | karpogory
# Processing Record 17 of Set 7 | worland
# Processing Record 18 of Set 7 | lorengau
# Processing Record 19 of Set 7 | gouyave
# Processing Record 20 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 21 of Set 7 | sakakah
# Processing Record 22 of Set 7 | konongo
# Processing Record 23 of Set 7 | vilyuysk
# Processing Record 24 of Set 7 | kjopsvik
# Processing Record 25 of Set 7 | mar del plata
# Processing Record 26 of Set 7 | ngunguru
# Processing Record 27 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 7 | calella
# Processing Record 29 of Set 7 | los llanos de aridane
# Processing Record 30 of Set 7 | richards bay
# Processing Record 31 of Set 7 | yei
# Processing Record 32 of Set 7 | namatanai
# Processing Record 33 of Set 7 | preeceville
# Processing Record 34 of Set 7 | alamos
# Processing Record 35 of Set 7 | shubarkuduk
# Processing Record 36 of Set 7 | maniitsoq
# Processing Record 37 of Set 7 | tabou
# Processing Record 38 of Set 7 | svetlogorsk
# Processing Record 39 of Set 7 | luderitz
# Processing Record 40 of Set 7 | katsina
# Processing Record 41 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 7 | gillette
# Processing Record 43 of Set 7 | maumere
# Processing Record 44 of Set 7 | qasigiannguit
# Processing Record 45 of Set 7 | ahipara
# Processing Record 46 of Set 7 | tambura
# Processing Record 47 of Set 7 | san vicente
# Processing Record 48 of Set 7 | jutai
# Processing Record 49 of Set 7 | shimoda
# Processing Record 50 of Set 7 | mataundh
# Processing Record 1 of Set 8 | yumen
# Processing Record 2 of Set 8 | alpena
# Processing Record 3 of Set 8 | beira
# Processing Record 4 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 8 | awbari
# Processing Record 6 of Set 8 | mana
# Processing Record 7 of Set 8 | macau
# Processing Record 8 of Set 8 | requena
# Processing Record 9 of Set 8 | la sarre
# Processing Record 10 of Set 8 | poso
# Processing Record 11 of Set 8 | sur
# Processing Record 12 of Set 8 | trincomalee
# Processing Record 13 of Set 8 | eirunepe
# Processing Record 14 of Set 8 | tocopilla
# Processing Record 15 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 8 | tura
# Processing Record 17 of Set 8 | manggar
# Processing Record 18 of Set 8 | dingle
# Processing Record 19 of Set 8 | hit
# Processing Record 20 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | harper
# Processing Record 22 of Set 8 | sitka
# Processing Record 23 of Set 8 | katobu
# Processing Record 24 of Set 8 | rawah
# Processing Record 25 of Set 8 | banda aceh
# Processing Record 26 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 8 | qaqortoq
# Processing Record 28 of Set 8 | novoilinsk
# Processing Record 29 of Set 8 | miraflores
# Processing Record 30 of Set 8 | koster
# Processing Record 31 of Set 8 | muncar
# Processing Record 32 of Set 8 | valparaiso
# Processing Record 33 of Set 8 | lata
# Processing Record 34 of Set 8 | vaitape
# Processing Record 35 of Set 8 | koson
# Processing Record 36 of Set 8 | itarema
# Processing Record 37 of Set 8 | makat
# Processing Record 38 of Set 8 | lotofaga
# Processing Record 39 of Set 8 | rheinau
# Processing Record 40 of Set 8 | dolzhanskaya
# Processing Record 41 of Set 8 | manicore
# Processing Record 42 of Set 8 | kavieng
# Processing Record 43 of Set 8 | quibor
# Processing Record 44 of Set 8 | rathcoole
# Processing Record 45 of Set 8 | viru
# Processing Record 46 of Set 8 | saint-georges
# Processing Record 47 of Set 8 | vung tau
# Processing Record 48 of Set 8 | narsaq
# Processing Record 49 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 8 | qarchi gak
# Processing Record 1 of Set 9 | caravelas
# Processing Record 2 of Set 9 | mabaruma
# Processing Record 3 of Set 9 | yurimaguas
# Processing Record 4 of Set 9 | magnor
# Processing Record 5 of Set 9 | mamou
# Processing Record 6 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 7 of Set 9 | necochea
# Processing Record 8 of Set 9 | ovalle
# Processing Record 9 of Set 9 | pavlodolskaya
# Processing Record 10 of Set 9 | carutapera
# Processing Record 11 of Set 9 | rudbar
# Processing Record 12 of Set 9 | nogliki
# Processing Record 13 of Set 9 | nokaneng
# Processing Record 14 of Set 9 | clyde river
# Processing Record 15 of Set 9 | bonfim
# Processing Record 16 of Set 9 | kerema
# Processing Record 17 of Set 9 | lagoa
# Processing Record 18 of Set 9 | saint-augustin
# Processing Record 19 of Set 9 | rio grande
# Processing Record 20 of Set 9 | ust-uda
# Processing Record 21 of Set 9 | laguna
# Processing Record 22 of Set 9 | inirida
# Processing Record 23 of Set 9 | limerick
# Processing Record 24 of Set 9 | hokitika
# Processing Record 25 of Set 9 | pandamatenga
# Processing Record 26 of Set 9 | tautira
# Processing Record 27 of Set 9 | shache
# Processing Record 28 of Set 9 | avera
# Processing Record 29 of Set 9 | goderich
# Processing Record 30 of Set 9 | malinovskiy
# Processing Record 31 of Set 9 | phan thiet
# Processing Record 32 of Set 9 | kendari
# Processing Record 33 of Set 9 | lavrentiya
# Processing Record 34 of Set 9 | havelock
# Processing Record 35 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 9 | quatre cocos
# Processing Record 37 of Set 9 | cayenne
# Processing Record 38 of Set 9 | loviisa
# Processing Record 39 of Set 9 | henties bay
# Processing Record 40 of Set 9 | ketchikan
# Processing Record 41 of Set 9 | anaco
# Processing Record 42 of Set 9 | hambantota
# Processing Record 43 of Set 9 | gazanjyk
# Processing Record 44 of Set 9 | dukat
# Processing Record 45 of Set 9 | aksarka
# Processing Record 46 of Set 9 | yulara
# Processing Record 47 of Set 9 | shreveport
# Processing Record 48 of Set 9 | angoche
# Processing Record 49 of Set 9 | jalu
# Processing Record 50 of Set 9 | belmonte
# Processing Record 1 of Set 10 | bilibino
# Processing Record 2 of Set 10 | katsuura
# Processing Record 3 of Set 10 | hofn
# Processing Record 4 of Set 10 | scottsbluff
# Processing Record 5 of Set 10 | dakoro
# Processing Record 6 of Set 10 | mandiana
# Processing Record 7 of Set 10 | temerloh
# Processing Record 8 of Set 10 | collie
# Processing Record 9 of Set 10 | biryukove
# Processing Record 10 of Set 10 | yagoua
# Processing Record 11 of Set 10 | abeche
# Processing Record 12 of Set 10 | kurumkan
# Processing Record 13 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 10 | maku
# Processing Record 15 of Set 10 | tessalit
# Processing Record 16 of Set 10 | kirakira
# Processing Record 17 of Set 10 | shahr-e babak
# Processing Record 18 of Set 10 | radchenko
# Processing Record 19 of Set 10 | owando
# Processing Record 20 of Set 10 | fort-shevchenko
# Processing Record 21 of Set 10 | aksu
# Processing Record 22 of Set 10 | pampa
# Processing Record 23 of Set 10 | gap
# Processing Record 24 of Set 10 | sumter
# Processing Record 25 of Set 10 | charlottetown
# Processing Record 26 of Set 10 | north bend
# Processing Record 27 of Set 10 | leua
# Processing Record 28 of Set 10 | faratsiho
# Processing Record 29 of Set 10 | tarauaca
# Processing Record 30 of Set 10 | camapua
# Processing Record 31 of Set 10 | san juan
# Processing Record 32 of Set 10 | vao
# Processing Record 33 of Set 10 | cannes
# Processing Record 34 of Set 10 | shingu
# Processing Record 35 of Set 10 | kamenka
# Processing Record 36 of Set 10 | kulhudhuffushi
# Processing Record 37 of Set 10 | bereda
# Processing Record 38 of Set 10 | borogontsy
# Processing Record 39 of Set 10 | chernyshevskiy
# Processing Record 40 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 41 of Set 10 | jiuquan
# Processing Record 42 of Set 10 | dharchula
# Processing Record 43 of Set 10 | santa maria
# Processing Record 44 of Set 10 | konevo
# Processing Record 45 of Set 10 | ocampo
# Processing Record 46 of Set 10 | banjarmasin
# Processing Record 47 of Set 10 | saldanha
# Processing Record 48 of Set 10 | abancay
# Processing Record 49 of Set 10 | severo-kurilsk
# Processing Record 50 of Set 10 | nago
# Processing Record 1 of Set 11 | omaruru
# Processing Record 2 of Set 11 | victoria
# Processing Record 3 of Set 11 | vanavara
# Processing Record 4 of Set 11 | juneau
# Processing Record 5 of Set 11 | tuatapere
# Processing Record 6 of Set 11 | bera
# Processing Record 7 of Set 11 | vallenar
# Processing Record 8 of Set 11 | namibe
# Processing Record 9 of Set 11 | betamcherla
# Processing Record 10 of Set 11 | zaysan
# Processing Record 11 of Set 11 | gourcy
# Processing Record 12 of Set 11 | yongchang
# Processing Record 13 of Set 11 | san quintin
# Processing Record 14 of Set 11 | ancud
# Processing Record 15 of Set 11 | koumac
# Processing Record 16 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 11 | kieta
# Processing Record 20 of Set 11 | nsanje
# Processing Record 21 of Set 11 | port blair
# Processing Record 22 of Set 11 | nabire
# Processing Record 23 of Set 11 | okhotsk
# Processing Record 24 of Set 11 | sibenik
# Processing Record 25 of Set 11 | yaan
# Processing Record 26 of Set 11 | vite
# Processing Record 27 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 11 | tono
# Processing Record 29 of Set 11 | naze
# Processing Record 30 of Set 11 | urusha
# Processing Record 31 of Set 11 | kalmunai
# Processing Record 32 of Set 11 | kiama
# Processing Record 33 of Set 11 | mackay
# Processing Record 34 of Set 11 | niceville
# Processing Record 35 of Set 11 | yamada
# Processing Record 36 of Set 11 | siyabuswa
# Processing Record 37 of Set 11 | minot
# Processing Record 38 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 11 | tomigusuku
# Processing Record 41 of Set 11 | the valley
# Processing Record 42 of Set 11 | qiongshan
# Processing Record 43 of Set 11 | lasa
# Processing Record 44 of Set 11 | thames
# Processing Record 45 of Set 11 | shu
# Processing Record 46 of Set 11 | krasnoselkup
# Processing Record 47 of Set 11 | tabuk
# Processing Record 48 of Set 11 | esmeraldas
# Processing Record 49 of Set 11 | linxia
# Processing Record 50 of Set 11 | hunchun
# Processing Record 1 of Set 12 | wellington
# Processing Record 2 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 12 | ugoofaaru
# Processing Record 4 of Set 12 | revelstoke
# Processing Record 5 of Set 12 | meulaboh
# Processing Record 6 of Set 12 | mezen
# Processing Record 7 of Set 12 | burnie
# Processing Record 8 of Set 12 | alvorada
# Processing Record 9 of Set 12 | ingham
# Processing Record 10 of Set 12 | mogadishu
# Processing Record 11 of Set 12 | suoyarvi
# Processing Record 12 of Set 12 | kununurra
# Processing Record 13 of Set 12 | bonthe
# Processing Record 14 of Set 12 | bubaque
# Processing Record 15 of Set 12 | mount gambier
# Processing Record 16 of Set 12 | valkeala
# Processing Record 17 of Set 12 | santa cruz de la palma
# Processing Record 18 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 19 of Set 12 | prince rupert
# Processing Record 20 of Set 12 | yantal
# Processing Record 21 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 22 of Set 12 | santa vitoria do palmar
# Processing Record 23 of Set 12 | price
# Processing Record 24 of Set 12 | marzuq
# Processing Record 25 of Set 12 | mount isa
# Processing Record 26 of Set 12 | tarakan
# Processing Record 27 of Set 12 | praia da vitoria
# Processing Record 28 of Set 12 | genhe
# Processing Record 29 of Set 12 | bambanglipuro
# Processing Record 30 of Set 12 | sargatskoye
# Processing Record 31 of Set 12 | daru
# Processing Record 32 of Set 12 | newcastle
# Processing Record 33 of Set 12 | santa catalina
# Processing Record 34 of Set 12 | salalah
# Processing Record 35 of Set 12 | nurota
# Processing Record 36 of Set 12 | novobiryusinskiy
# Processing Record 37 of Set 12 | akyab
# Processing Record 38 of Set 12 | eureka
# Processing Record 39 of Set 12 | belaya gora
# Processing Record 40 of Set 12 | passau
# Processing Record 41 of Set 12 | sao filipe
# Processing Record 42 of Set 12 | bathsheba
# Processing Record 43 of Set 12 | vila velha
# Processing Record 44 of Set 12 | coos bay
# Processing Record 45 of Set 12 | bahia de caraquez
# Processing Record 46 of Set 12 | oktyabrskoye
# Processing Record 47 of Set 12 | varna
# Processing Record 48 of Set 12 | sept-iles
# Processing Record 49 of Set 12 | walsall
# Processing Record 50 of Set 12 | lazaro cardenas
# Processing Record 1 of Set 13 | santa fe
# Processing Record 2 of Set 13 | yucca valley
# Processing Record 3 of Set 13 | ulaangom
# Processing Record 4 of Set 13 | guerrero negro
# Processing Record 5 of Set 13 | wukari
# Processing Record 6 of Set 13 | prince george
# Processing Record 7 of Set 13 | skibbereen
# Processing Record 8 of Set 13 | merauke
# Processing Record 9 of Set 13 | phalaborwa
# Processing Record 10 of Set 13 | amasia
# Processing Record 11 of Set 13 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 12 of Set 13 | salinopolis
# Processing Record 13 of Set 13 | vertou
# Processing Record 14 of Set 13 | kaihua
# Processing Record 15 of Set 13 | westport
# Processing Record 16 of Set 13 | kobelyaky
# Processing Record 17 of Set 13 | wattegama
# Processing Record 18 of Set 13 | barreirinhas
# Processing Record 19 of Set 13 | tiznit
# Processing Record 20 of Set 13 | yellamanchili
# City not found. Skipping...
# Processing Record 21 of Set 13 | sarangani
# Processing Record 22 of Set 13 | southern pines
# Processing Record 23 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 13 | santiago
# Processing Record 25 of Set 13 | praya
# Processing Record 26 of Set 13 | juegang
# Processing Record 27 of Set 13 | calabozo
# Processing Record 28 of Set 13 | vestmanna
# Processing Record 29 of Set 13 | sabzevar
# Processing Record 30 of Set 13 | manbij
# Processing Record 31 of Set 13 | vila franca do campo
# Processing Record 32 of Set 13 | atchison
# Processing Record 33 of Set 13 | mugur-aksy
# Processing Record 34 of Set 13 | olafsvik
# Processing Record 35 of Set 13 | shakawe
# Processing Record 36 of Set 13 | santa cruz
# Processing Record 37 of Set 13 | boddam
# Processing Record 38 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 13 | bud
# Processing Record 40 of Set 13 | asilah
# Processing Record 41 of Set 13 | santa marta
# Processing Record 42 of Set 13 | cairns
# Processing Record 43 of Set 13 | ankara
# Processing Record 44 of Set 13 | san-pedro
# Processing Record 45 of Set 13 | nishihara
# Processing Record 46 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 47 of Set 13 | katete
# Processing Record 48 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 13 | ipixuna
# Processing Record 50 of Set 13 | rantepao
# Processing Record 1 of Set 14 | amlagora
# Processing Record 2 of Set 14 | owosso
# Processing Record 3 of Set 14 | samarai
# Processing Record 4 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 14 | wapi pathum
# Processing Record 6 of Set 14 | morondava
# Processing Record 7 of Set 14 | ankpa
# Processing Record 8 of Set 14 | nueve de julio
# Processing Record 9 of Set 14 | severo-yeniseyskiy
# Processing Record 10 of Set 14 | promissao
# Processing Record 11 of Set 14 | swan river
# Processing Record 12 of Set 14 | mashhad
# Processing Record 13 of Set 14 | san andres
# Processing Record 14 of Set 14 | zatoka
# Processing Record 15 of Set 14 | mamallapuram
# Processing Record 16 of Set 14 | uruacu
# Processing Record 17 of Set 14 | staszow
# Processing Record 18 of Set 14 | katherine
# Processing Record 19 of Set 14 | sirsi
# Processing Record 20 of Set 14 | kibala
# Processing Record 21 of Set 14 | yangambi
# Processing Record 22 of Set 14 | shitkino
# Processing Record 23 of Set 14 | viransehir
# Processing Record 24 of Set 14 | korla
# Processing Record 25 of Set 14 | benguela
# Processing Record 26 of Set 14 | aasiaat
# Processing Record 27 of Set 14 | mazamari
# Processing Record 28 of Set 14 | moultrie
# Processing Record 29 of Set 14 | meybod
# Processing Record 30 of Set 14 | conde
# Processing Record 31 of Set 14 | hirara
# Processing Record 32 of Set 14 | tupik
# Processing Record 33 of Set 14 | conceicao do araguaia
# Processing Record 34 of Set 14 | salvador
# Processing Record 35 of Set 14 | road town
# Processing Record 36 of Set 14 | honningsvag
# Processing Record 37 of Set 14 | muros
# Processing Record 38 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 39 of Set 14 | purepero
# Processing Record 40 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 14 | tortoli
# Processing Record 42 of Set 14 | keti bandar
# Processing Record 43 of Set 14 | jaciara
# Processing Record 44 of Set 14 | salo
# Processing Record 45 of Set 14 | chengde
# Processing Record 46 of Set 14 | sioux lookout
# Processing Record 47 of Set 14 | huilong
# Processing Record 48 of Set 14 | balezino
# Processing Record 49 of Set 14 | puerto narino
# Processing Record 50 of Set 14 | xining
# Processing Record 1 of Set 15 | beringovskiy
# Processing Record 2 of Set 15 | yerbogachen
# Processing Record 3 of Set 15 | kitoy
# Processing Record 4 of Set 15 | american fork
# Processing Record 5 of Set 15 | anadyr
# Processing Record 6 of Set 15 | abnub
# Processing Record 7 of Set 15 | crucea
# Processing Record 8 of Set 15 | rantauprapat
# Processing Record 9 of Set 15 | sao joao da barra
# Processing Record 10 of Set 15 | huejuquilla el alto
# Processing Record 11 of Set 15 | acajutla
# Processing Record 12 of Set 15 | luanda
# Processing Record 13 of Set 15 | palauig
# Processing Record 14 of Set 15 | kanth
# Processing Record 15 of Set 15 | asau
# Processing Record 16 of Set 15 | joao camara
# Processing Record 17 of Set 15 | boueni
# Processing Record 18 of Set 15 | taltal
# Processing Record 19 of Set 15 | isangel
# Processing Record 20 of Set 15 | singkang
# Processing Record 21 of Set 15 | vostok
# Processing Record 22 of Set 15 | emba
# Processing Record 23 of Set 15 | priiskovyy
# Processing Record 24 of Set 15 | gigmoto
# Processing Record 25 of Set 15 | lashio
# Processing Record 26 of Set 15 | sal rei
# Processing Record 27 of Set 15 | oranjemund
# Processing Record 28 of Set 15 | batsfjord
# Processing Record 29 of Set 15 | valley city
# Processing Record 30 of Set 15 | lodwar
# Processing Record 31 of Set 15 | bulawayo
# Processing Record 32 of Set 15 | hurricane
# Processing Record 33 of Set 15 | constitucion
# Processing Record 34 of Set 15 | tefe
# Processing Record 35 of Set 15 | kingisepp
# Processing Record 36 of Set 15 | aykhal
# Processing Record 37 of Set 15 | pontes e lacerda
# Processing Record 38 of Set 15 | dudinka
# Processing Record 39 of Set 15 | amzya
# Processing Record 40 of Set 15 | puerto madryn
# Processing Record 41 of Set 15 | kangaatsiaq
# Processing Record 42 of Set 15 | dabakala
# Processing Record 43 of Set 15 | muyezerskiy
# Processing Record 44 of Set 15 | aquiraz
# Processing Record 45 of Set 15 | kasongo-lunda
# Processing Record 46 of Set 15 | srivardhan
# Processing Record 47 of Set 15 | kachug
# Processing Record 48 of Set 15 | penzance
# Processing Record 49 of Set 15 | boguchany
# Processing Record 50 of Set 15 | jizan
# Processing Record 1 of Set 16 | chapais
# Processing Record 2 of Set 16 | ihiala
# Processing Record 3 of Set 16 | nancha
# Processing Record 4 of Set 16 | atbasar
# Processing Record 5 of Set 16 | uarini
# Processing Record 6 of Set 16 | kraslava
# Processing Record 7 of Set 16 | polyarnyy
# Processing Record 8 of Set 16 | hailin
# Processing Record 9 of Set 16 | nyuksenitsa
# Processing Record 10 of Set 16 | morehead
# Processing Record 11 of Set 16 | husavik
# Processing Record 12 of Set 16 | lhokseumawe
# Processing Record 13 of Set 16 | novosergiyevka
# Processing Record 14 of Set 16 | togur
# Processing Record 15 of Set 16 | phangnga
# Processing Record 16 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 17 of Set 16 | bahia blanca
# Processing Record 18 of Set 16 | urumqi
# Processing Record 19 of Set 16 | matagami
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mildura -34.2000  142.1500     60.08        70           1
# 1       Port Hardy  50.6996 -127.4199     51.98        66         100
# 2            Kapaa  22.0752 -159.3190     82.38        75          22
# 3         Menongue -14.6585   17.6910     52.07        69           1
# 4        Geraldton -28.7667  114.6000     70.21        78          40
# 5          Tondano   1.3038  124.9112     77.09        64          39
# 6         Taseyevo  57.2169   94.8978     76.10        36          64
# 7          Labuhan  -6.8844  112.2051     82.54        78         100
# 8  Arraial Do Cabo -22.9661  -42.0278     68.85        80          96
# 9           Nautla  20.2167  -96.7833     79.11        77          16
#
#    Wind Speed Country Current Description
# 0       13.15      AU           clear sky
# 1        6.91      CA     overcast clouds
# 2        4.00      US          few clouds
# 3        4.56      AO           clear sky
# 4        8.05      AU    scattered clouds
# 5        1.03      ID    scattered clouds
# 6       11.54      RU       broken clouds
# 7        6.71      ID     overcast clouds
# 8       15.43      BR     overcast clouds
# 9       13.73      MX          few clouds

# %%
# Reorganize column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
