# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests

! pip install gmaps

import gmaps
# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)
# Out:
# Requirement already satisfied: gmaps in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (5.1.0)
# Requirement already satisfied: six in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.29.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: pickleshare in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.18.0)
# Requirement already satisfied: appnope in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: matplotlib-inline in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (58.0.4)
# Requirement already satisfied: pygments in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (2.10.0)
# Requirement already satisfied: decorator in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (5.1.0)
# Requirement already satisfied: backcall in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (6.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.5)
# Requirement already satisfied: nbconvert in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.0)
# Requirement already satisfied: prometheus-client in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: argon2-cffi in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: jinja2 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: cffi>=1.0.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.6)
# Requirement already satisfied: pycparser in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: defusedxml in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: testpath in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: bleach in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: async-generator in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: packaging in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.0)
# Requirement already satisfied: webencodings in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/nehlaamin/opt/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0     Mildura      AU -34.2000  142.1500     60.08        70
# 1        1  Port Hardy      CA  50.6996 -127.4199     51.98        66
# 2        2       Kapaa      US  22.0752 -159.3190     82.38        75
# 3        3    Menongue      AO -14.6585   17.6910     52.07        69
# 4        4   Geraldton      AU -28.7667  114.6000     70.21        78
#
#    Cloudiness  Wind Speed Current Description
# 0           1       13.15           clear sky
# 1         100        6.91     overcast clouds
# 2          22        4.00          few clouds
# 3           1        4.56           clear sky
# 4          40        8.05    scattered clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 65
# What is the maximum temperature you would like for your trip? 85

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 2         2            Kapaa      US  22.0752 -159.3190     82.38        75
# 4         4        Geraldton      AU -28.7667  114.6000     70.21        78
# 5         5          Tondano      ID   1.3038  124.9112     77.09        64
# 6         6         Taseyevo      RU  57.2169   94.8978     76.10        36
# 7         7          Labuhan      ID  -6.8844  112.2051     82.54        78
# 8         8  Arraial Do Cabo      BR -22.9661  -42.0278     68.85        80
# 9         9           Nautla      MX  20.2167  -96.7833     79.11        77
# 14       14          Rikitea      PF -23.1203 -134.9692     76.95        74
# 17       17        Cape Town      ZA -33.9258   18.4232     76.10        38
# 22       22        Mahebourg      MU -20.4081   57.7000     69.26        64
#
#     Cloudiness  Wind Speed Current Description
# 2           22        4.00          few clouds
# 4           40        8.05    scattered clouds
# 5           39        1.03    scattered clouds
# 6           64       11.54       broken clouds
# 7          100        6.71     overcast clouds
# 8           96       15.43     overcast clouds
# 9           16       13.73          few clouds
# 14          65       21.85       broken clouds
# 17           0       10.00           clear sky
# 22           4       15.28           clear sky

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                355
# City                   355
# Country                352
# Lat                    355
# Lng                    355
# Max Temp               355
# Humidity               355
# Cloudiness             355
# Wind Speed             355
# Current Description    355
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna(axis=0, how='any')

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 2             Kapaa      US     82.38          few clouds  22.0752 -159.3190
# 4         Geraldton      AU     70.21    scattered clouds -28.7667  114.6000
# 5           Tondano      ID     77.09    scattered clouds   1.3038  124.9112
# 6          Taseyevo      RU     76.10       broken clouds  57.2169   94.8978
# 7           Labuhan      ID     82.54     overcast clouds  -6.8844  112.2051
# 8   Arraial Do Cabo      BR     68.85     overcast clouds -22.9661  -42.0278
# 9            Nautla      MX     79.11          few clouds  20.2167  -96.7833
# 14          Rikitea      PF     76.95       broken clouds -23.1203 -134.9692
# 17        Cape Town      ZA     76.10           clear sky -33.9258   18.4232
# 22        Mahebourg      MU     69.26           clear sky -20.4081   57.7000
#
#    Hotel Name
# 2
# 4
# 5
# 6
# 7
# 8
# 9
# 14
# 17
# 22

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
print("Starting to find hotels")
# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
        
print("Finished finding hotels")
# Out:
# Starting to find hotels
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Finished finding hotels

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df.count()
# Out:
# City                   352
# Country                352
# Max Temp               352
# Current Description    352
# Lat                    352
# Lng                    352
# Hotel Name             352
# dtype: int64

# %%
# 8a. Create the output File (CSV)
# Create the output file (CSV).
output_data_file = "WeatherPy_Vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

# 11b. Display the figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
